# %%
library(glmnet)
library(dplyr)
library(tidyverse)
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ readr     2.1.5
# ✔ ggplot2   3.5.1     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::expand() masks Matrix::expand()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ tidyr::pack()   masks Matrix::pack()
# ✖ tidyr::unpack() masks Matrix::unpack()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
train_data <- read.csv("train.csv")
test_data <- read.csv("test.csv", colClasses = c("id" = "character"))

# %%
train_data <- train_data %>%
    mutate(price = substr(price, 2, nchar(price)),
          host_response_rate = substr(host_response_rate, 1, nchar(host_response_rate) - 1),
          host_acceptance_rate = substr(host_acceptance_rate, 1, nchar(host_acceptance_rate) - 1)) %>%
    mutate(price = as.numeric(price),
           host_response_rate = as.numeric(host_response_rate),
           host_acceptance_rate = as.numeric(host_acceptance_rate))
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `price = as.numeric(price)`.
# Caused by warning:
# ! NAs introduced by coercion”

# %%
y <- train_data$monthly_revenue
x <- makeX(train_data[ , c('property_type',
                           'accommodates','beds',
                           'minimum_nights','maximum_nights',
                           'maximum_nights_avg_ntm','availability_30','availability_60','availability_90',
                           'availability_365','number_of_reviews','number_of_reviews_ltm',
                           'review_scores_rating','review_scores_accuracy','review_scores_cleanliness',
                           'review_scores_value','instant_bookable')],
          na.impute = TRUE)
ggplot(train_data) +
geom_point(x = property_type, y = monthly_revenue)
# Out:
# Error in eval(expr, envir, enclos): object 'property_type' not found
# Traceback:
#
# 1. geom_point(x = property_type, y = monthly_revenue)
# 2. layer(data = data, mapping = mapping, stat = stat, geom = GeomPoint,
#  .     position = position, show.legend = show.legend, inherit.aes = inherit.aes,
#  .     params = list2(na.rm = na.rm, ...))
# 3. list2(na.rm = na.rm, ...)

# %%
cv_model <- cv.glmnet(x, y, alpha = 1)

best_lambda <- cv_model$lambda.min
best_lambda

plot(cv_model)
# Out:
# [1] 11.07992
# plot without title

# %%
best_model <- glmnet(x, y, alpha = 1, lambda = best_lambda)
coef(best_model)
# Out:
# 64 x 1 sparse Matrix of class "dgCMatrix"
#                                                            s0
# (Intercept)                                     -1.173598e+03
# property_typeBoat                                1.982718e+02
# property_typeCamper/RV                          -2.560492e+02
# property_typeCasa particular                    -7.035023e+02
# property_typeCave                                .
# property_typeEntire bungalow                     2.315227e+02
# property_typeEntire cabin                        .
# property_typeEntire condo                        .
# property_typeEntire cottage                      7.620891e+01
# property_typeEntire guest suite                 -2.161307e+01
# property_typeEntire guesthouse                   .
# property_typeEntire home                         9.625996e+02
# property_typeEntire loft                        -2.790738e+01
# property_typeEntire place                        1.725507e+01
# property_typeEntire rental unit                  .
# property_typeEntire serviced apartment          -5.019501e+01
# property_typeEntire timeshare                    .
# property_typeEntire townhouse                    8.261987e+01
# property_typeEntire vacation home                .
# property_typeEntire villa                       -4.673620e+02
# property_typePrivate room in bed and breakfast  -3.597716e+01
# property_typePrivate room in boat                1.906891e+02
# property_typePrivate room in bungalow            2.815865e+02
# property_typePrivate room in camper/rv          -4.340237e+02
# property_typePrivate room in casa particular     .
# property_typePrivate room in castle              .
# property_typePrivate room in condo               3.189622e+02
# property_typePrivate room in guest suite         .
# property_typePrivate room in guesthouse          .
# property_typePrivate room in home                6.041616e+01
# property_typePrivate room in loft                .
# property_typePrivate room in rental unit         4.420699e+01
# property_typePrivate room in serviced apartment -5.353898e+01
# property_typePrivate room in tiny home           9.522412e+01
# property_typePrivate room in townhouse           .
# property_typePrivate room in villa              -8.299771e+01
# property_typeRoom in aparthotel                  .
# property_typeRoom in bed and breakfast           .
# property_typeRoom in boutique hotel              3.230629e+01
# property_typeRoom in hotel                      -2.674429e+02
# property_typeShared room in condo                .
# property_typeShared room in home                 .
# property_typeShared room in loft                 .
# property_typeShared room in rental unit          .
# property_typeShared room in villa               -5.254559e+02
# property_typeTiny home                           .
# property_typeTower                               .
# accommodates                                     1.978125e+02
# beds                                             3.207335e+01
# minimum_nights                                  -4.962519e-01
# maximum_nights                                   3.930066e-02
# maximum_nights_avg_ntm                           4.641063e-02
# availability_30                                  .
# availability_60                                  .
# availability_90                                  .
# availability_365                                -4.258567e-01
# number_of_reviews                                .
# number_of_reviews_ltm                            .
# review_scores_rating                             2.756901e+02
# review_scores_accuracy                           .
# review_scores_cleanliness                        3.719765e+01
# review_scores_value                              1.148343e+02
# instant_bookablef                                5.897388e+01
# instant_bookablet                               -2.529467e-11

# %%
pred_y <- predict(best_model, s = best_lambda, newx = x)

sst <- sum((y - mean(y))^2)
sse <- sum((pred_y - y)^2)

rsq <- 1 - sse/sst
rsq
sse
# Out:
# [1] 0.2981136
# [1] 6688540065

# %%
head(pred_y)
head(y)
# Out:
#   s1
# 1 2327.390
# 2 1936.730
# 3 2235.903
# 4 2339.344
# 5 1847.790
# 6 1330.552
# [1] 2108 2730 2254 3187 3479    0

# %%
test_x <- makeX(test_data[ , c('id',
                                 'host_response_time',
                                 'host_response_rate','host_acceptance_rate',
                                 'host_is_superhost','host_listings_count',
                                 'host_total_listings_count',
                                 'neighbourhood','neighbourhood_cleansed','property_type','room_type',
                                 'accommodates','beds',
                                 'price','minimum_nights','maximum_nights','minimum_nights_avg_ntm',
                                 'maximum_nights_avg_ntm','availability_30','availability_60','availability_90',
                                 'availability_365','number_of_reviews','number_of_reviews_ltm',
                                 'review_scores_rating','review_scores_accuracy','review_scores_cleanliness',
                                 'review_scores_checkin','review_scores_communication','review_scores_location',
                                 'review_scores_value','instant_bookable','calculated_host_listings_count',
                                 'reviews_per_month')],
          na.impute = TRUE)
test_pred_y <- predict(best_model, s = best_lambda, newx = test_x)
# Out:
# Error in predict.glmnet(best_model, s = best_lambda, newx = test_x): The number of variables in newx must be 118
# Traceback:
#
# 1. predict(best_model, s = best_lambda, newx = test_x)
# 2. predict.elnet(best_model, s = best_lambda, newx = test_x)
# 3. NextMethod("predict")
# 4. predict.glmnet(best_model, s = best_lambda, newx = test_x)
# 5. stop(paste0("The number of variables in newx must be ", p))

# %%
train_data_entire <- train_data %>%
    filter(grepl("Entire", property_type, fixed = TRUE))

# %%
train_data_entire$property_type
# Out:
#    [1] "Entire home"               "Entire guest suite"
#    [3] "Entire guest suite"        "Entire home"
#    [5] "Entire guest suite"        "Entire condo"
#    [7] "Entire condo"              "Entire condo"
#    [9] "Entire rental unit"        "Entire townhouse"
#   [11] "Entire home"               "Entire home"
#   [13] "Entire condo"              "Entire home"
#   [15] "Entire rental unit"        "Entire condo"
#   [17] "Entire rental unit"        "Entire rental unit"
#   [19] "Entire rental unit"        "Entire home"
#   [21] "Entire home"               "Entire home"
#   [23] "Entire rental unit"        "Entire home"
#   [25] "Entire condo"              "Entire home"
#   [27] "Entire home"               "Entire guest suite"
#   [29] "Entire home"               "Entire guest suite"
#   [31] "Entire condo"              "Entire home"
#   [33] "Entire rental unit"        "Entire rental unit"
#   [35] "Entire condo"              "Entire condo"
#   [37] "Entire home"               "Entire guest suite"
#   [39] "Entire rental unit"        "Entire rental unit"
#   [41] "Entire rental unit"        "Entire home"
#   [43] "Entire rental unit"        "Entire condo"
#   [45] "Entire condo"              "Entire condo"
#   [47] "Entire guest suite"        "Entire guest suite"
#   [49] "Entire condo"              "Entire rental unit"
#   [51] "Entire condo"              "Entire home"
#   [53] "Entire condo"              "Entire home"
#   [55] "Entire rental unit"        "Entire home"
#   [57] "Entire rental unit"        "Entire home"
#   [59] "Entire home"               "Entire loft"
#   [61] "Entire home"               "Entire serviced apartment"
#   [63] "Entire guest suite"        "Entire home"
#   [65] "Entire loft"               "Entire rental unit"
#   [67] "Entire rental unit"        "Entire condo"
#   [69] "Entire rental unit"        "Entire rental unit"
#   [71] "Entire rental unit"        "Entire condo"
#   [73] "Entire rental unit"        "Entire condo"
#   [75] "Entire rental unit"        "Entire condo"
#   [77] "Entire home"               "Entire condo"
#   [79] "Entire condo"              "Entire home"
#   [81] "Entire home"               "Entire guest suite"
#   [83] "Entire condo"              "Entire rental unit"
#   [85] "Entire home"               "Entire rental unit"
#   [87] "Entire condo"              "Entire rental unit"
#   [89] "Entire home"               "Entire home"
#   [91] "Entire rental unit"        "Entire condo"
#   [93] "Entire serviced apartment" "Entire condo"
#   [95] "Entire condo"              "Entire rental unit"
#   [97] "Entire home"               "Entire rental unit"
#   [99] "Entire home"               "Entire home"
#  [101] "Entire home"               "Entire guest suite"
#  [103] "Entire rental unit"        "Entire condo"
#  [105] "Entire rental unit"        "Entire rental unit"
#  [107] "Entire rental unit"        "Entire rental unit"
#  [109] "Entire condo"              "Entire townhouse"
#  [111] "Entire guest suite"        "Entire home"
#  [113] "Entire condo"              "Entire home"
#  [115] "Entire rental unit"        "Entire home"
#  [117] "Entire condo"              "Entire home"
#  [119] "Entire rental unit"        "Entire home"
#  [121] "Entire guest suite"        "Entire condo"
#  [123] "Entire condo"              "Entire condo"
#  [125] "Entire condo"              "Entire home"
#  [127] "Entire home"               "Entire condo"
#  [129] "Entire condo"              "Entire guest suite"
#  [131] "Entire condo"              "Entire condo"
#  [133] "Entire home"               "Entire rental unit"
#  [135] "Entire guest suite"        "Entire home"
#  [137] "Entire condo"              "Entire condo"
#  [139] "Entire loft"               "Entire rental unit"
#  [141] "Entire condo"              "Entire rental unit"
#  [143] "Entire home"               "Entire home"
#  [145] "Entire loft"               "Entire home"
#  [147] "Entire home"               "Entire guest suite"
#  [149] "Entire rental unit"        "Entire rental unit"
#  [151] "Entire guest suite"        "Entire rental unit"
#  [153] "Entire condo"              "Entire rental unit"
#  [155] "Entire home"               "Entire townhouse"
#  [157] "Entire condo"              "Entire home"
#  [159] "Entire home"               "Entire condo"
#  [161] "Entire home"               "Entire condo"
#  [163] "Entire home"               "Entire condo"
#  [165] "Entire loft"               "Entire rental unit"
#  [167] "Entire serviced apartment" "Entire guest suite"
#  [169] "Entire rental unit"        "Entire rental unit"
#  [171] "Entire rental unit"        "Entire condo"
#  [173] "Entire rental unit"        "Entire condo"
#  [175] "Entire rental unit"        "Entire home"
#  [177] "Entire guest suite"        "Entire home"
#  [179] "Entire guest suite"        "Entire guest suite"
#  [181] "Entire guest suite"        "Entire guesthouse"
#  [183] "Entire rental unit"        "Entire guest suite"
#  [185] "Entire condo"              "Entire rental unit"
#  [187] "Entire rental unit"        "Entire rental unit"
#  [189] "Entire guest suite"        "Entire rental unit"
#  [191] "Entire loft"               "Entire home"
#  [193] "Entire rental unit"        "Entire guest suite"
#  [195] "Entire home"               "Entire condo"
#  [197] "Entire rental unit"        "Entire home"
#  [199] "Entire rental unit"        "Entire guest suite"
#  [201] "Entire home"               "Entire home"
#  [203] "Entire home"               "Entire rental unit"
#  [205] "Entire home"               "Entire condo"
#  [207] "Entire rental unit"        "Entire townhouse"
#  [209] "Entire guest suite"        "Entire rental unit"
#  [211] "Entire home"               "Entire guest suite"
#  [213] "Entire rental unit"        "Entire condo"
#  [215] "Entire rental unit"        "Entire home"
#  [217] "Entire home"               "Entire guest suite"
#  [219] "Entire rental unit"        "Entire home"
#  [221] "Entire condo"              "Entire rental unit"
#  [223] "Entire rental unit"        "Entire rental unit"
#  [225] "Entire condo"              "Entire condo"
#  [227] "Entire rental unit"        "Entire condo"
#  [229] "Entire townhouse"          "Entire rental unit"
#  [231] "Entire rental unit"        "Entire townhouse"
#  [233] "Entire rental unit"        "Entire guest suite"
#  [235] "Entire guest suite"        "Entire rental unit"
#  [237] "Entire rental unit"        "Entire condo"
#  [239] "Entire townhouse"          "Entire rental unit"
#  [241] "Entire home"               "Entire condo"
#  [243] "Entire home"               "Entire rental unit"
#  [245] "Entire home"               "Entire condo"
#  [247] "Entire guest suite"        "Entire condo"
#  [249] "Entire condo"              "Entire rental unit"
#  [251] "Entire condo"              "Entire rental unit"
#  [253] "Entire home"               "Entire guesthouse"
#  [255] "Entire rental unit"        "Entire guest suite"
#  [257] "Entire rental unit"        "Entire condo"
#  [259] "Entire home"               "Entire condo"
#  [261] "Entire guesthouse"         "Entire rental unit"
#  [263] "Entire rental unit"        "Entire condo"
#  [265] "Entire condo"              "Entire rental unit"
#  [267] "Entire home"               "Entire rental unit"
#  [269] "Entire guest suite"        "Entire home"
#  [271] "Entire condo"              "Entire rental unit"
#  [273] "Entire rental unit"        "Entire guest suite"
#  [275] "Entire home"               "Entire townhouse"
#  [277] "Entire rental unit"        "Entire condo"
#  [279] "Entire rental unit"        "Entire condo"
#  [281] "Entire condo"              "Entire condo"
#  [283] "Entire condo"              "Entire condo"
#  [285] "Entire home"               "Entire condo"
#  [287] "Entire townhouse"          "Entire condo"
#  [289] "Entire condo"              "Entire rental unit"
#  [291] "Entire guest suite"        "Entire condo"
#  [293] "Entire home"               "Entire rental unit"
#  [295] "Entire rental unit"        "Entire rental unit"
#  [297] "Entire condo"              "Entire condo"
#  [299] "Entire guest suite"        "Entire guest suite"
#  [301] "Entire loft"               "Entire rental unit"
#  [303] "Entire condo"              "Entire home"
#  [305] "Entire condo"              "Entire condo"
#  [307] "Entire condo"              "Entire rental unit"
#  [309] "Entire rental unit"        "Entire home"
#  [311] "Entire rental unit"        "Entire condo"
#  [313] "Entire condo"              "Entire home"
#  [315] "Entire rental unit"        "Entire condo"
#  [317] "Entire rental unit"        "Entire home"
#  [319] "Entire rental unit"        "Entire condo"
#  [321] "Entire home"               "Entire home"
#  [323] "Entire condo"              "Entire condo"
#  [325] "Entire home"               "Entire condo"
#  [327] "Entire rental unit"        "Entire condo"
#  [329] "Entire home"               "Entire condo"
#  [331] "Entire loft"               "Entire home"
#  [333] "Entire rental unit"        "Entire rental unit"
#  [335] "Entire rental unit"        "Entire condo"
#  [337] "Entire home"               "Entire home"
#  [339] "Entire rental unit"        "Entire home"
#  [341] "Entire guest suite"        "Entire guest suite"
#  [343] "Entire guest suite"        "Entire condo"
#  [345] "Entire condo"              "Entire rental unit"
#  [347] "Entire rental unit"        "Entire condo"
#  [349] "Entire home"               "Entire condo"
#  [351] "Entire condo"              "Entire condo"
#  [353] "Entire condo"              "Entire rental unit"
#  [355] "Entire home"               "Entire condo"
#  [357] "Entire rental unit"        "Entire home"
#  [359] "Entire townhouse"          "Entire home"
#  [361] "Entire guesthouse"         "Entire home"
#  [363] "Entire home"               "Entire home"
#  [365] "Entire home"               "Entire home"
#  [367] "Entire home"               "Entire guest suite"
#  [369] "Entire condo"              "Entire rental unit"
#  [371] "Entire rental unit"        "Entire home"
#  [373] "Entire rental unit"        "Entire condo"
#  [375] "Entire guesthouse"         "Entire rental unit"
#  [377] "Entire condo"              "Entire condo"
#  [379] "Entire rental unit"        "Entire condo"
#  [381] "Entire home"               "Entire rental unit"
#  [383] "Entire home"               "Entire guest suite"
#  [385] "Entire guesthouse"         "Entire condo"
#  [387] "Entire condo"              "Entire rental unit"
#  [389] "Entire condo"              "Entire home"
#  [391] "Entire rental unit"        "Entire rental unit"
#  [393] "Entire rental unit"        "Entire rental unit"
#  [395] "Entire home"               "Entire home"
#  [397] "Entire rental unit"        "Entire home"
#  [399] "Entire rental unit"        "Entire home"
#  [401] "Entire rental unit"        "Entire rental unit"
#  [403] "Entire condo"              "Entire home"
#  [405] "Entire home"               "Entire home"
#  [407] "Entire home"               "Entire home"
#  [409] "Entire condo"              "Entire condo"
#  [411] "Entire rental unit"        "Entire guest suite"
#  [413] "Entire home"               "Entire rental unit"
#  [415] "Entire condo"              "Entire condo"
#  [417] "Entire rental unit"        "Entire rental unit"
#  [419] "Entire condo"              "Entire rental unit"
#  [421] "Entire rental unit"        "Entire condo"
#  [423] "Entire condo"              "Entire rental unit"
#  [425] "Entire condo"              "Entire loft"
#  [427] "Entire serviced apartment" "Entire rental unit"
#  [429] "Entire rental unit"        "Entire rental unit"
#  [431] "Entire rental unit"        "Entire home"
#  [433] "Entire townhouse"          "Entire rental unit"
#  [435] "Entire guest suite"        "Entire guest suite"
#  [437] "Entire rental unit"        "Entire rental unit"
#  [439] "Entire rental unit"        "Entire guest suite"
#  [441] "Entire condo"              "Entire rental unit"
#  [443] "Entire condo"              "Entire condo"
#  [445] "Entire rental unit"        "Entire home"
#  [447] "Entire condo"              "Entire rental unit"
#  [449] "Entire rental unit"        "Entire home"
#  [451] "Entire guest suite"        "Entire rental unit"
#  [453] "Entire home"               "Entire condo"
#  [455] "Entire guest suite"        "Entire rental unit"
#  [457] "Entire rental unit"        "Entire home"
#  [459] "Entire condo"              "Entire home"
#  [461] "Entire rental unit"        "Entire condo"
#  [463] "Entire rental unit"        "Entire rental unit"
#  [465] "Entire home"               "Entire rental unit"
#  [467] "Entire guest suite"        "Entire guest suite"
#  [469] "Entire guest suite"        "Entire home"
#  [471] "Entire condo"              "Entire guesthouse"
#  [473] "Entire home"               "Entire home"
#  [475] "Entire guest suite"        "Entire condo"
#  [477] "Entire loft"               "Entire condo"
#  [479] "Entire guest suite"        "Entire condo"
#  [481] "Entire rental unit"        "Entire condo"
#  [483] "Entire rental unit"        "Entire rental unit"
#  [485] "Entire condo"              "Entire condo"
#  [487] "Entire rental unit"        "Entire condo"
#  [489] "Entire rental unit"        "Entire condo"
#  [491] "Entire home"               "Entire rental unit"
#  [493] "Entire rental unit"        "Entire home"
#  [495] "Entire rental unit"        "Entire loft"
#  [497] "Entire rental unit"        "Entire guest suite"
#  [499] "Entire home"               "Entire rental unit"
#  [501] "Entire home"               "Entire condo"
#  [503] "Entire home"               "Entire home"
#  [505] "Entire condo"              "Entire rental unit"
#  [507] "Entire home"               "Entire townhouse"
#  [509] "Entire condo"              "Entire home"
#  [511] "Entire condo"              "Entire rental unit"
#  [513] "Entire condo"              "Entire rental unit"
#  [515] "Entire guest suite"        "Entire condo"
#  [517] "Entire home"               "Entire home"
#  [519] "Entire condo"              "Entire rental unit"
#  [521] "Entire condo"              "Entire loft"
#  [523] "Entire loft"               "Entire rental unit"
#  [525] "Entire condo"              "Entire home"
#  [527] "Entire condo"              "Entire home"
#  [529] "Entire guest suite"        "Entire home"
#  [531] "Entire home"               "Entire rental unit"
#  [533] "Entire home"               "Entire guest suite"
#  [535] "Entire rental unit"        "Entire home"
#  [537] "Entire guest suite"        "Entire condo"
#  [539] "Entire condo"              "Entire rental unit"
#  [541] "Entire loft"               "Entire condo"
#  [543] "Entire loft"               "Entire timeshare"
#  [545] "Entire guest suite"        "Entire home"
#  [547] "Entire rental unit"        "Entire condo"
#  [549] "Entire guest suite"        "Entire townhouse"
#  [551] "Entire vacation home"      "Entire rental unit"
#  [553] "Entire rental unit"        "Entire guesthouse"
#  [555] "Entire rental unit"        "Entire guest suite"
#  [557] "Entire condo"              "Entire home"
#  [559] "Entire guesthouse"         "Entire home"
#  [561] "Entire condo"              "Entire home"
#  [563] "Entire home"               "Entire rental unit"
#  [565] "Entire rental unit"        "Entire loft"
#  [567] "Entire condo"              "Entire guest suite"
#  [569] "Entire guest suite"        "Entire condo"
#  [571] "Entire rental unit"        "Entire rental unit"
#  [573] "Entire condo"              "Entire home"
#  [575] "Entire rental unit"        "Entire rental unit"
#  [577] "Entire home"               "Entire condo"
#  [579] "Entire guest suite"        "Entire condo"
#  [581] "Entire condo"              "Entire condo"
#  [583] "Entire rental unit"        "Entire home"
#  [585] "Entire rental unit"        "Entire guest suite"
#  [587] "Entire home"               "Entire rental unit"
#  [589] "Entire condo"              "Entire condo"
#  [591] "Entire rental unit"        "Entire rental unit"
#  [593] "Entire condo"              "Entire rental unit"
#  [595] "Entire condo"              "Entire condo"
#  [597] "Entire guest suite"        "Entire home"
#  [599] "Entire home"               "Entire rental unit"
#  [601] "Entire townhouse"          "Entire home"
#  [603] "Entire condo"              "Entire condo"
#  [605] "Entire townhouse"          "Entire guest suite"
#  [607] "Entire home"               "Entire rental unit"
#  [609] "Entire serviced apartment" "Entire townhouse"
#  [611] "Entire guest suite"        "Entire townhouse"
#  [613] "Entire rental unit"        "Entire guest suite"
#  [615] "Entire home"               "Entire condo"
#  [617] "Entire condo"              "Entire guest suite"
#  [619] "Entire home"               "Entire rental unit"
#  [621] "Entire condo"              "Entire home"
#  [623] "Entire rental unit"        "Entire home"
#  [625] "Entire home"               "Entire guesthouse"
#  [627] "Entire condo"              "Entire home"
#  [629] "Entire rental unit"        "Entire townhouse"
#  [631] "Entire rental unit"        "Entire rental unit"
#  [633] "Entire rental unit"        "Entire rental unit"
#  [635] "Entire condo"              "Entire rental unit"
#  [637] "Entire home"               "Entire home"
#  [639] "Entire rental unit"        "Entire loft"
#  [641] "Entire condo"              "Entire condo"
#  [643] "Entire loft"               "Entire rental unit"
#  [645] "Entire condo"              "Entire home"
#  [647] "Entire rental unit"        "Entire rental unit"
#  [649] "Entire condo"              "Entire condo"
#  [651] "Entire townhouse"          "Entire guest suite"
#  [653] "Entire rental unit"        "Entire guesthouse"
#  [655] "Entire home"               "Entire condo"
#  [657] "Entire condo"              "Entire condo"
#  [659] "Entire home"               "Entire guest suite"
#  [661] "Entire rental unit"        "Entire rental unit"
#  [663] "Entire home"               "Entire condo"
#  [665] "Entire guest suite"        "Entire rental unit"
#  [667] "Entire rental unit"        "Entire townhouse"
#  [669] "Entire rental unit"        "Entire rental unit"
#  [671] "Entire rental unit"        "Entire townhouse"
#  [673] "Entire rental unit"        "Entire condo"
#  [675] "Entire rental unit"        "Entire condo"
#  [677] "Entire rental unit"        "Entire rental unit"
#  [679] "Entire condo"              "Entire guest suite"
#  [681] "Entire rental unit"        "Entire cabin"
#  [683] "Entire condo"              "Entire rental unit"
#  [685] "Entire condo"              "Entire rental unit"
#  [687] "Entire condo"              "Entire rental unit"
#  [689] "Entire home"               "Entire serviced apartment"
#  [691] "Entire guest suite"        "Entire home"
#  [693] "Entire home"               "Entire condo"
#  [695] "Entire guest suite"        "Entire home"
#  [697] "Entire home"               "Entire condo"
#  [699] "Entire guest suite"        "Entire condo"
#  [701] "Entire condo"              "Entire loft"
#  [703] "Entire guest suite"        "Entire vacation home"
#  [705] "Entire home"               "Entire home"
#  [707] "Entire serviced apartment" "Entire rental unit"
#  [709] "Entire condo"              "Entire home"
#  [711] "Entire condo"              "Entire rental unit"
#  [713] "Entire home"               "Entire guest suite"
#  [715] "Entire rental unit"        "Entire condo"
#  [717] "Entire condo"              "Entire rental unit"
#  [719] "Entire condo"              "Entire condo"
#  [721] "Entire condo"              "Entire condo"
#  [723] "Entire condo"              "Entire loft"
#  [725] "Entire guest suite"        "Entire rental unit"
#  [727] "Entire condo"              "Entire rental unit"
#  [729] "Entire condo"              "Entire home"
#  [731] "Entire rental unit"        "Entire rental unit"
#  [733] "Entire guest suite"        "Entire home"
#  [735] "Entire guest suite"        "Entire guest suite"
#  [737] "Entire home"               "Entire guest suite"
#  [739] "Entire home"               "Entire condo"
#  [741] "Entire rental unit"        "Entire rental unit"
#  [743] "Entire rental unit"        "Entire rental unit"
#  [745] "Entire condo"              "Entire condo"
#  [747] "Entire guest suite"        "Entire rental unit"
#  [749] "Entire guest suite"        "Entire rental unit"
#  [751] "Entire rental unit"        "Entire rental unit"
#  [753] "Entire serviced apartment" "Entire rental unit"
#  [755] "Entire rental unit"        "Entire guesthouse"
#  [757] "Entire rental unit"        "Entire condo"
#  [759] "Entire townhouse"          "Entire guest suite"
#  [761] "Entire rental unit"        "Entire rental unit"
#  [763] "Entire rental unit"        "Entire rental unit"
#  [765] "Entire home"               "Entire rental unit"
#  [767] "Entire condo"              "Entire home"
#  [769] "Entire condo"              "Entire condo"
#  [771] "Entire loft"               "Entire home"
#  [773] "Entire loft"               "Entire rental unit"
#  [775] "Entire guesthouse"         "Entire rental unit"
#  [777] "Entire rental unit"        "Entire home"
#  [779] "Entire condo"              "Entire townhouse"
#  [781] "Entire condo"              "Entire condo"
#  [783] "Entire condo"              "Entire condo"
#  [785] "Entire condo"              "Entire rental unit"
#  [787] "Entire home"               "Entire home"
#  [789] "Entire condo"              "Entire guest suite"
#  [791] "Entire condo"              "Entire rental unit"
#  [793] "Entire home"               "Entire rental unit"
#  [795] "Entire home"               "Entire condo"
#  [797] "Entire home"               "Entire guest suite"
#  [799] "Entire condo"              "Entire rental unit"
#  [801] "Entire guest suite"        "Entire guest suite"
#  [803] "Entire home"               "Entire rental unit"
#  [805] "Entire loft"               "Entire home"
#  [807] "Entire condo"              "Entire home"
#  [809] "Entire guesthouse"         "Entire rental unit"
#  [811] "Entire rental unit"        "Entire loft"
#  [813] "Entire rental unit"        "Entire rental unit"
#  [815] "Entire rental unit"        "Entire condo"
#  [817] "Entire rental unit"        "Entire guest suite"
#  [819] "Entire guest suite"        "Entire rental unit"
#  [821] "Entire rental unit"        "Entire home"
#  [823] "Entire condo"              "Entire home"
#  [825] "Entire rental unit"        "Entire condo"
#  [827] "Entire condo"              "Entire rental unit"
#  [829] "Entire condo"              "Entire rental unit"
#  [831] "Entire home"               "Entire home"
#  [833] "Entire rental unit"        "Entire rental unit"
#  [835] "Entire guest suite"        "Entire rental unit"
#  [837] "Entire townhouse"          "Entire condo"
#  [839] "Entire guest suite"        "Entire condo"
#  [841] "Entire rental unit"        "Entire rental unit"
#  [843] "Entire condo"              "Entire rental unit"
#  [845] "Entire home"               "Entire rental unit"
#  [847] "Entire home"               "Entire guest suite"
#  [849] "Entire guest suite"        "Entire rental unit"
#  [851] "Entire condo"              "Entire rental unit"
#  [853] "Entire condo"              "Entire rental unit"
#  [855] "Entire rental unit"        "Entire rental unit"
#  [857] "Entire guest suite"        "Entire home"
#  [859] "Entire rental unit"        "Entire guest suite"
#  [861] "Entire condo"              "Entire home"
#  [863] "Entire townhouse"          "Entire condo"
#  [865] "Entire home"               "Entire condo"
#  [867] "Entire rental unit"        "Entire rental unit"
#  [869] "Entire guesthouse"         "Entire condo"
#  [871] "Entire guest suite"        "Entire home"
#  [873] "Entire townhouse"          "Entire guest suite"
#  [875] "Entire rental unit"        "Entire home"
#  [877] "Entire rental unit"        "Entire home"
#  [879] "Entire condo"              "Entire condo"
#  [881] "Entire home"               "Entire loft"
#  [883] "Entire guest suite"        "Entire rental unit"
#  [885] "Entire guest suite"        "Entire guest suite"
#  [887] "Entire rental unit"        "Entire rental unit"
#  [889] "Entire rental unit"        "Entire serviced apartment"
#  [891] "Entire condo"              "Entire home"
#  [893] "Entire rental unit"        "Entire home"
#  [895] "Entire serviced apartment" "Entire rental unit"
#  [897] "Entire rental unit"        "Entire condo"
#  [899] "Entire home"               "Entire condo"
#  [901] "Entire home"               "Entire rental unit"
#  [903] "Entire loft"               "Entire rental unit"
#  [905] "Entire rental unit"        "Entire rental unit"
#  [907] "Entire loft"               "Entire guesthouse"
#  [909] "Entire home"               "Entire condo"
#  [911] "Entire condo"              "Entire rental unit"
#  [913] "Entire rental unit"        "Entire condo"
#  [915] "Entire condo"              "Entire condo"
#  [917] "Entire home"               "Entire guesthouse"
#  [919] "Entire guest suite"        "Entire condo"
#  [921] "Entire rental unit"        "Entire guesthouse"
#  [923] "Entire home"               "Entire condo"
#  [925] "Entire condo"              "Entire rental unit"
#  [927] "Entire home"               "Entire condo"
#  [929] "Entire rental unit"        "Entire condo"
#  [931] "Entire home"               "Entire condo"
#  [933] "Entire home"               "Entire rental unit"
#  [935] "Entire condo"              "Entire rental unit"
#  [937] "Entire condo"              "Entire guest suite"
#  [939] "Entire condo"              "Entire guest suite"
#  [941] "Entire condo"              "Entire home"
#  [943] "Entire home"               "Entire home"
#  [945] "Entire home"               "Entire rental unit"
#  [947] "Entire condo"              "Entire rental unit"
#  [949] "Entire rental unit"        "Entire rental unit"
#  [951] "Entire condo"              "Entire townhouse"
#  [953] "Entire rental unit"        "Entire guest suite"
#  [955] "Entire home"               "Entire rental unit"
#  [957] "Entire guest suite"        "Entire rental unit"
#  [959] "Entire rental unit"        "Entire rental unit"
#  [961] "Entire guest suite"        "Entire rental unit"
#  [963] "Entire home"               "Entire rental unit"
#  [965] "Entire serviced apartment" "Entire serviced apartment"
#  [967] "Entire rental unit"        "Entire rental unit"
#  [969] "Entire home"               "Entire rental unit"
#  [971] "Entire condo"              "Entire rental unit"
#  [973] "Entire home"               "Entire home"
#  [975] "Entire rental unit"        "Entire condo"
#  [977] "Entire rental unit"        "Entire rental unit"
#  [979] "Entire guest suite"        "Entire rental unit"
#  [981] "Entire rental unit"        "Entire rental unit"
#  [983] "Entire condo"              "Entire condo"
#  [985] "Entire condo"              "Entire condo"
#  [987] "Entire loft"               "Entire rental unit"
#  [989] "Entire rental unit"        "Entire condo"
#  [991] "Entire rental unit"        "Entire loft"
#  [993] "Entire rental unit"        "Entire condo"
#  [995] "Entire townhouse"          "Entire guest suite"
#  [997] "Entire rental unit"        "Entire guest suite"
#  [999] "Entire condo"              "Entire rental unit"
# [1001] "Entire townhouse"          "Entire guest suite"
# [1003] "Entire condo"              "Entire home"
# [1005] "Entire rental unit"        "Entire home"
# [1007] "Entire condo"              "Entire rental unit"
# [1009] "Entire condo"              "Entire home"
# [1011] "Entire home"               "Entire condo"
# [1013] "Entire condo"              "Entire rental unit"
# [1015] "Entire home"               "Entire condo"
# [1017] "Entire rental unit"        "Entire rental unit"
# [1019] "Entire condo"              "Entire condo"
# [1021] "Entire home"               "Entire guest suite"
# [1023] "Entire home"               "Entire condo"
# [1025] "Entire rental unit"        "Entire guest suite"
# [1027] "Entire home"               "Entire condo"
# [1029] "Entire condo"              "Entire rental unit"
# [1031] "Entire home"               "Entire rental unit"
# [1033] "Entire home"               "Entire rental unit"
# [1035] "Entire condo"              "Entire condo"
# [1037] "Entire condo"              "Entire rental unit"
# [1039] "Entire condo"              "Entire rental unit"
# [1041] "Entire rental unit"        "Entire home"
# [1043] "Entire condo"              "Entire home"
# [1045] "Entire home"               "Entire loft"
# [1047] "Entire condo"              "Entire rental unit"
# [1049] "Entire rental unit"        "Entire condo"
# [1051] "Entire rental unit"        "Entire home"
# [1053] "Entire rental unit"        "Entire rental unit"
# [1055] "Entire home"               "Entire rental unit"
# [1057] "Entire rental unit"        "Entire rental unit"
# [1059] "Entire condo"              "Entire condo"
# [1061] "Entire rental unit"        "Entire rental unit"
# [1063] "Entire home"               "Entire home"
# [1065] "Entire rental unit"        "Entire guest suite"
# [1067] "Entire rental unit"        "Entire condo"
# [1069] "Entire rental unit"        "Entire condo"
# [1071] "Entire rental unit"        "Entire condo"
# [1073] "Entire guest suite"        "Entire rental unit"
# [1075] "Entire home"               "Entire home"
# [1077] "Entire condo"              "Entire guest suite"
# [1079] "Entire condo"              "Entire rental unit"
# [1081] "Entire villa"              "Entire guest suite"
# [1083] "Entire home"               "Entire rental unit"
# [1085] "Entire condo"              "Entire rental unit"
# [1087] "Entire condo"              "Entire home"
# [1089] "Entire rental unit"        "Entire home"
# [1091] "Entire rental unit"        "Entire condo"
# [1093] "Entire rental unit"        "Entire serviced apartment"
# [1095] "Entire rental unit"        "Entire guest suite"
# [1097] "Entire home"               "Entire condo"
# [1099] "Entire condo"              "Entire condo"
# [1101] "Entire rental unit"        "Entire guesthouse"
# [1103] "Entire condo"              "Entire home"
# [1105] "Entire home"               "Entire guest suite"
# [1107] "Entire home"               "Entire guest suite"
# [1109] "Entire rental unit"        "Entire home"
# [1111] "Entire rental unit"        "Entire townhouse"
# [1113] "Entire home"               "Entire loft"
# [1115] "Entire rental unit"        "Entire guest suite"
# [1117] "Entire guest suite"        "Entire condo"
# [1119] "Entire condo"              "Entire home"
# [1121] "Entire rental unit"        "Entire loft"
# [1123] "Entire rental unit"        "Entire rental unit"
# [1125] "Entire condo"              "Entire home"
# [1127] "Entire condo"              "Entire rental unit"
# [1129] "Entire guest suite"        "Entire guest suite"
# [1131] "Entire guest suite"        "Entire home"
# [1133] "Entire condo"              "Entire home"
# [1135] "Entire guest suite"        "Entire condo"
# [1137] "Entire home"               "Entire condo"
# [1139] "Entire condo"              "Entire condo"
# [1141] "Entire condo"              "Entire condo"
# [1143] "Entire home"               "Entire home"
# [1145] "Entire condo"              "Entire rental unit"
# [1147] "Entire condo"              "Entire guest suite"
# [1149] "Entire condo"              "Entire guesthouse"
# [1151] "Entire home"               "Entire rental unit"
# [1153] "Entire home"               "Entire condo"
# [1155] "Entire rental unit"        "Entire rental unit"
# [1157] "Entire home"               "Entire home"
# [1159] "Entire rental unit"        "Entire rental unit"
# [1161] "Entire rental unit"        "Entire guest suite"
# [1163] "Entire rental unit"        "Entire guesthouse"
# [1165] "Entire rental unit"        "Entire home"
# [1167] "Entire condo"              "Entire loft"
# [1169] "Entire guest suite"        "Entire rental unit"
# [1171] "Entire guest suite"        "Entire home"
# [1173] "Entire guest suite"        "Entire rental unit"
# [1175] "Entire condo"              "Entire condo"
# [1177] "Entire condo"              "Entire home"
# [1179] "Entire serviced apartment" "Entire rental unit"
# [1181] "Entire bungalow"           "Entire rental unit"
# [1183] "Entire rental unit"        "Entire bungalow"
# [1185] "Entire rental unit"        "Entire rental unit"
# [1187] "Entire rental unit"        "Entire home"
# [1189] "Entire rental unit"        "Entire guest suite"
# [1191] "Entire loft"               "Entire rental unit"
# [1193] "Entire home"               "Entire guest suite"
# [1195] "Entire rental unit"        "Entire condo"
# [1197] "Entire condo"              "Entire guest suite"
# [1199] "Entire rental unit"        "Entire loft"
# [1201] "Entire condo"              "Entire home"
# [1203] "Entire townhouse"          "Entire home"
# [1205] "Entire home"               "Entire rental unit"
# [1207] "Entire loft"               "Entire condo"
# [1209] "Entire rental unit"        "Entire rental unit"
# [1211] "Entire rental unit"        "Entire rental unit"
# [1213] "Entire home"               "Entire rental unit"
# [1215] "Entire loft"               "Entire condo"
# [1217] "Entire home"               "Entire guest suite"
# [1219] "Entire rental unit"        "Entire condo"
# [1221] "Entire rental unit"        "Entire rental unit"
# [1223] "Entire rental unit"        "Entire home"
# [1225] "Entire home"               "Entire rental unit"
# [1227] "Entire rental unit"        "Entire condo"
# [1229] "Entire home"               "Entire condo"
# [1231] "Entire rental unit"        "Entire guest suite"
# [1233] "Entire condo"              "Entire rental unit"
# [1235] "Entire home"               "Entire home"
# [1237] "Entire rental unit"        "Entire rental unit"
# [1239] "Entire condo"              "Entire guesthouse"
# [1241] "Entire condo"              "Entire rental unit"
# [1243] "Entire rental unit"        "Entire condo"
# [1245] "Entire rental unit"        "Entire rental unit"
# [1247] "Entire condo"              "Entire rental unit"
# [1249] "Entire home"               "Entire condo"
# [1251] "Entire rental unit"        "Entire home"
# [1253] "Entire condo"              "Entire guest suite"
# [1255] "Entire condo"              "Entire condo"
# [1257] "Entire home"               "Entire rental unit"
# [1259] "Entire rental unit"        "Entire rental unit"
# [1261] "Entire guest suite"        "Entire condo"
# [1263] "Entire rental unit"        "Entire condo"
# [1265] "Entire guest suite"        "Entire condo"
# [1267] "Entire rental unit"        "Entire rental unit"
# [1269] "Entire rental unit"        "Entire rental unit"
# [1271] "Entire home"               "Entire condo"
# [1273] "Entire condo"              "Entire guest suite"
# [1275] "Entire condo"              "Entire condo"
# [1277] "Entire loft"               "Entire home"
# [1279] "Entire guest suite"        "Entire rental unit"
# [1281] "Entire rental unit"        "Entire condo"
# [1283] "Entire condo"              "Entire rental unit"
# [1285] "Entire rental unit"        "Entire home"
# [1287] "Entire rental unit"        "Entire home"
# [1289] "Entire condo"              "Entire guest suite"
# [1291] "Entire home"               "Entire rental unit"
# [1293] "Entire condo"              "Entire home"
# [1295] "Entire rental unit"        "Entire home"
# [1297] "Entire rental unit"        "Entire guest suite"
# [1299] "Entire rental unit"        "Entire rental unit"
# [1301] "Entire condo"              "Entire home"
# [1303] "Entire townhouse"          "Entire rental unit"
# [1305] "Entire guest suite"        "Entire guest suite"
# [1307] "Entire home"               "Entire condo"
# [1309] "Entire condo"              "Entire rental unit"
# [1311] "Entire rental unit"        "Entire home"
# [1313] "Entire rental unit"        "Entire home"
# [1315] "Entire rental unit"        "Entire rental unit"
# [1317] "Entire home"               "Entire rental unit"
# [1319] "Entire rental unit"        "Entire rental unit"
# [1321] "Entire home"               "Entire rental unit"
# [1323] "Entire home"               "Entire home"
# [1325] "Entire townhouse"          "Entire rental unit"
# [1327] "Entire home"               "Entire home"
# [1329] "Entire rental unit"        "Entire guest suite"
# [1331] "Entire loft"               "Entire condo"
# [1333] "Entire guest suite"        "Entire rental unit"
# [1335] "Entire condo"              "Entire condo"
# [1337] "Entire guest suite"        "Entire home"
# [1339] "Entire condo"              "Entire home"
# [1341] "Entire home"               "Entire home"
# [1343] "Entire condo"              "Entire home"
# [1345] "Entire home"               "Entire rental unit"
# [1347] "Entire guest suite"        "Entire guest suite"
# [1349] "Entire condo"              "Entire home"
# [1351] "Entire home"               "Entire home"
# [1353] "Entire condo"              "Entire condo"
# [1355] "Entire rental unit"        "Entire rental unit"
# [1357] "Entire rental unit"        "Entire rental unit"
# [1359] "Entire loft"               "Entire home"
# [1361] "Entire home"               "Entire home"
# [1363] "Entire home"               "Entire townhouse"
# [1365] "Entire condo"              "Entire rental unit"
# [1367] "Entire condo"              "Entire home"
# [1369] "Entire condo"              "Entire condo"
# [1371] "Entire guest suite"        "Entire home"
# [1373] "Entire condo"              "Entire home"
# [1375] "Entire rental unit"        "Entire rental unit"
# [1377] "Entire home"               "Entire townhouse"
# [1379] "Entire condo"              "Entire home"
# [1381] "Entire rental unit"        "Entire rental unit"
# [1383] "Entire rental unit"        "Entire guest suite"
# [1385] "Entire rental unit"        "Entire home"
# [1387] "Entire condo"              "Entire home"
# [1389] "Entire rental unit"        "Entire home"
# [1391] "Entire guest suite"        "Entire home"
# [1393] "Entire condo"              "Entire home"
# [1395] "Entire condo"              "Entire guesthouse"
# [1397] "Entire home"               "Entire rental unit"
# [1399] "Entire guest suite"        "Entire townhouse"
# [1401] "Entire rental unit"        "Entire guest suite"
# [1403] "Entire home"               "Entire rental unit"
# [1405] "Entire condo"              "Entire condo"
# [1407] "Entire home"               "Entire home"
# [1409] "Entire home"               "Entire guest suite"
# [1411] "Entire loft"               "Entire home"
# [1413] "Entire rental unit"        "Entire guest suite"
# [1415] "Entire guest suite"        "Entire home"
# [1417] "Entire home"               "Entire guest suite"
# [1419] "Entire condo"              "Entire condo"
# [1421] "Entire serviced apartment" "Entire rental unit"
# [1423] "Entire condo"              "Entire home"
# [1425] "Entire guest suite"        "Entire home"
# [1427] "Entire condo"              "Entire guest suite"
# [1429] "Entire loft"               "Entire condo"
# [1431] "Entire home"               "Entire condo"
# [1433] "Entire condo"              "Entire serviced apartment"
# [1435] "Entire guest suite"        "Entire home"
# [1437] "Entire home"               "Entire rental unit"
# [1439] "Entire rental unit"        "Entire condo"
# [1441] "Entire condo"              "Entire condo"
# [1443] "Entire rental unit"        "Entire serviced apartment"
# [1445] "Entire condo"              "Entire condo"
# [1447] "Entire rental unit"        "Entire condo"
# [1449] "Entire loft"               "Entire guest suite"
# [1451] "Entire home"               "Entire home"
# [1453] "Entire condo"              "Entire condo"
# [1455] "Entire condo"              "Entire guesthouse"
# [1457] "Entire place"              "Entire guest suite"
# [1459] "Entire home"               "Entire rental unit"
# [1461] "Entire condo"              "Entire home"
# [1463] "Entire home"               "Entire rental unit"
# [1465] "Entire rental unit"        "Entire rental unit"
# [1467] "Entire condo"              "Entire home"
# [1469] "Entire guest suite"        "Entire rental unit"
# [1471] "Entire rental unit"        "Entire home"
# [1473] "Entire condo"              "Entire guest suite"
# [1475] "Entire condo"              "Entire home"
# [1477] "Entire guesthouse"         "Entire condo"
# [1479] "Entire guest suite"        "Entire condo"
# [1481] "Entire guest suite"        "Entire rental unit"
# [1483] "Entire rental unit"        "Entire rental unit"
# [1485] "Entire rental unit"        "Entire condo"
# [1487] "Entire guest suite"        "Entire home"
# [1489] "Entire home"               "Entire rental unit"
# [1491] "Entire rental unit"        "Entire condo"
# [1493] "Entire condo"              "Entire guesthouse"
# [1495] "Entire rental unit"        "Entire condo"
# [1497] "Entire home"               "Entire guest suite"
# [1499] "Entire rental unit"        "Entire rental unit"
# [1501] "Entire rental unit"        "Entire home"
# [1503] "Entire condo"              "Entire condo"
# [1505] "Entire condo"              "Entire townhouse"
# [1507] "Entire condo"              "Entire rental unit"
# [1509] "Entire rental unit"        "Entire guest suite"
# [1511] "Entire rental unit"        "Entire rental unit"
# [1513] "Entire townhouse"          "Entire guest suite"
# [1515] "Entire loft"               "Entire home"
# [1517] "Entire rental unit"        "Entire guest suite"
# [1519] "Entire rental unit"        "Entire guest suite"
# [1521] "Entire home"               "Entire rental unit"
# ...
# [3765] "Entire rental unit"        "Entire loft"
# [3767] "Entire guesthouse"         "Entire condo"
# [3769] "Entire rental unit"        "Entire guest suite"
# [3771] "Entire rental unit"        "Entire home"
# [3773] "Entire rental unit"        "Entire condo"
# [3775] "Entire rental unit"        "Entire guest suite"
# [3777] "Entire serviced apartment" "Entire guest suite"
# [3779] "Entire condo"              "Entire condo"
# [3781] "Entire home"               "Entire serviced apartment"
# [3783] "Entire home"               "Entire condo"
# [3785] "Entire home"               "Entire guest suite"
# [3787] "Entire home"               "Entire condo"
# [3789] "Entire loft"               "Entire rental unit"
# [3791] "Entire rental unit"        "Entire rental unit"
# [3793] "Entire townhouse"          "Entire home"
# [3795] "Entire guest suite"        "Entire condo"
# [3797] "Entire guest suite"        "Entire rental unit"
# [3799] "Entire condo"              "Entire rental unit"
# [3801] "Entire condo"              "Entire home"
# [3803] "Entire loft"               "Entire guest suite"
# [3805] "Entire guest suite"        "Entire condo"
# [3807] "Entire rental unit"        "Entire home"
# [3809] "Entire townhouse"          "Entire rental unit"
# [3811] "Entire condo"              "Entire home"
# [3813] "Entire home"               "Entire rental unit"
# [3815] "Entire rental unit"        "Entire condo"
# [3817] "Entire guest suite"        "Entire home"
# [3819] "Entire guest suite"        "Entire condo"
# [3821] "Entire condo"              "Entire rental unit"
# [3823] "Entire condo"              "Entire rental unit"
# [3825] "Entire serviced apartment" "Entire loft"
# [3827] "Entire rental unit"        "Entire home"
# [3829] "Entire condo"              "Entire loft"
# [3831] "Entire townhouse"          "Entire home"
# [3833] "Entire home"               "Entire guesthouse"
# [3835] "Entire rental unit"        "Entire condo"
# [3837] "Entire serviced apartment" "Entire guest suite"
# [3839] "Entire home"               "Entire home"
# [3841] "Entire home"               "Entire rental unit"
# [3843] "Entire condo"              "Entire condo"
# [3845] "Entire rental unit"        "Entire rental unit"
# [3847] "Entire condo"              "Entire home"
# [3849] "Entire rental unit"        "Entire home"
# [3851] "Entire guest suite"        "Entire home"
# [3853] "Entire rental unit"        "Entire home"
# [3855] "Entire condo"              "Entire rental unit"
# [3857] "Entire guest suite"        "Entire rental unit"
# [3859] "Entire condo"              "Entire condo"
# [3861] "Entire home"               "Entire rental unit"
# [3863] "Entire condo"              "Entire rental unit"
# [3865] "Entire condo"              "Entire home"
# [3867] "Entire home"               "Entire home"
# [3869] "Entire rental unit"        "Entire rental unit"
# [3871] "Entire home"               "Entire guest suite"
# [3873] "Entire rental unit"        "Entire rental unit"
# [3875] "Entire condo"              "Entire rental unit"
# [3877] "Entire condo"              "Entire home"
# [3879] "Entire home"               "Entire home"
# [3881] "Entire townhouse"          "Entire rental unit"
# [3883] "Entire condo"              "Entire home"
# [3885] "Entire rental unit"        "Entire condo"
# [3887] "Entire home"               "Entire rental unit"
# [3889] "Entire rental unit"        "Entire home"
# [3891] "Entire townhouse"          "Entire rental unit"
# [3893] "Entire rental unit"        "Entire loft"
# [3895] "Entire rental unit"        "Entire home"
# [3897] "Entire home"               "Entire condo"
# [3899] "Entire guest suite"        "Entire guest suite"
# [3901] "Entire guesthouse"         "Entire rental unit"
# [3903] "Entire rental unit"        "Entire rental unit"
# [3905] "Entire home"               "Entire condo"
# [3907] "Entire guest suite"        "Entire rental unit"
# [3909] "Entire home"               "Entire guest suite"
# [3911] "Entire home"               "Entire rental unit"
# [3913] "Entire home"               "Entire guest suite"
# [3915] "Entire home"               "Entire home"
# [3917] "Entire home"               "Entire condo"
# [3919] "Entire rental unit"        "Entire bungalow"
# [3921] "Entire condo"              "Entire condo"
# [3923] "Entire condo"              "Entire condo"
# [3925] "Entire home"               "Entire home"
# [3927] "Entire home"               "Entire home"
# [3929] "Entire guesthouse"         "Entire rental unit"
# [3931] "Entire rental unit"        "Entire condo"
# [3933] "Entire home"               "Entire rental unit"
# [3935] "Entire guest suite"        "Entire condo"
# [3937] "Entire guest suite"        "Entire rental unit"
# [3939] "Entire condo"              "Entire guest suite"
# [3941] "Entire rental unit"        "Entire home"
# [3943] "Entire rental unit"        "Entire rental unit"
# [3945] "Entire rental unit"        "Entire home"
# [3947] "Entire condo"              "Entire condo"
# [3949] "Entire rental unit"        "Entire rental unit"
# [3951] "Entire condo"              "Entire home"
# [3953] "Entire home"               "Entire rental unit"
# [3955] "Entire home"               "Entire condo"
# [3957] "Entire rental unit"        "Entire condo"
# [3959] "Entire rental unit"        "Entire rental unit"
# [3961] "Entire rental unit"        "Entire rental unit"
# [3963] "Entire home"               "Entire rental unit"
# [3965] "Entire condo"              "Entire condo"
# [3967] "Entire home"               "Entire guest suite"
# [3969] "Entire condo"              "Entire home"
# [3971] "Entire rental unit"        "Entire guest suite"
# [3973] "Entire rental unit"        "Entire rental unit"
# [3975] "Entire home"               "Entire rental unit"
# [3977] "Entire rental unit"        "Entire rental unit"
# [3979] "Entire condo"              "Entire condo"
# [3981] "Entire home"               "Entire condo"
# [3983] "Entire home"               "Entire home"
# [3985] "Entire rental unit"        "Entire rental unit"
# [3987] "Entire rental unit"        "Entire rental unit"
# [3989] "Entire condo"              "Entire condo"
# [3991] "Entire rental unit"        "Entire home"
# [3993] "Entire home"               "Entire condo"
# [3995] "Entire home"               "Entire rental unit"
# [3997] "Entire rental unit"        "Entire home"
# [3999] "Entire home"               "Entire condo"
# [4001] "Entire guest suite"        "Entire guesthouse"
# [4003] "Entire rental unit"        "Entire rental unit"
# [4005] "Entire rental unit"        "Entire rental unit"
# [4007] "Entire rental unit"        "Entire home"
# [4009] "Entire guest suite"        "Entire rental unit"
# [4011] "Entire guest suite"        "Entire rental unit"
# [4013] "Entire rental unit"        "Entire guest suite"
# [4015] "Entire home"               "Entire condo"
# [4017] "Entire rental unit"        "Entire rental unit"
# [4019] "Entire rental unit"        "Entire home"
# [4021] "Entire home"               "Entire villa"
# [4023] "Entire guest suite"        "Entire rental unit"
# [4025] "Entire condo"              "Entire home"
# [4027] "Entire home"               "Entire home"
# [4029] "Entire condo"              "Entire condo"
# [4031] "Entire home"               "Entire guest suite"
# [4033] "Entire rental unit"        "Entire home"
# [4035] "Entire rental unit"        "Entire rental unit"
# [4037] "Entire condo"              "Entire condo"
# [4039] "Entire home"               "Entire rental unit"
# [4041] "Entire rental unit"        "Entire home"
# [4043] "Entire rental unit"        "Entire guest suite"
# [4045] "Entire townhouse"          "Entire guest suite"
# [4047] "Entire loft"               "Entire guest suite"
# [4049] "Entire rental unit"        "Entire condo"
# [4051] "Entire home"               "Entire condo"
# [4053] "Entire guest suite"        "Entire rental unit"
# [4055] "Entire rental unit"        "Entire home"
# [4057] "Entire guest suite"        "Entire condo"
# [4059] "Entire home"               "Entire home"
# [4061] "Entire rental unit"        "Entire rental unit"
# [4063] "Entire guest suite"        "Entire guest suite"
# [4065] "Entire serviced apartment" "Entire rental unit"
# [4067] "Entire condo"              "Entire rental unit"
# [4069] "Entire condo"              "Entire condo"
# [4071] "Entire home"               "Entire rental unit"
# [4073] "Entire rental unit"        "Entire guest suite"
# [4075] "Entire home"               "Entire guest suite"
# [4077] "Entire home"               "Entire rental unit"
# [4079] "Entire rental unit"        "Entire home"
# [4081] "Entire condo"              "Entire rental unit"
# [4083] "Entire rental unit"        "Entire home"
# [4085] "Entire rental unit"        "Entire rental unit"
# [4087] "Entire guest suite"        "Entire rental unit"
# [4089] "Entire home"               "Entire rental unit"
# [4091] "Entire guesthouse"         "Entire villa"
# [4093] "Entire rental unit"        "Entire rental unit"
# [4095] "Entire rental unit"        "Entire rental unit"
# [4097] "Entire rental unit"        "Entire guest suite"
# [4099] "Entire condo"              "Entire rental unit"
# [4101] "Entire home"               "Entire loft"
# [4103] "Entire condo"              "Entire rental unit"
# [4105] "Entire rental unit"        "Entire rental unit"
# [4107] "Entire rental unit"        "Entire home"
# [4109] "Entire condo"              "Entire rental unit"
# [4111] "Entire rental unit"        "Entire home"
# [4113] "Entire guesthouse"         "Entire condo"
# [4115] "Entire condo"              "Entire home"
# [4117] "Entire rental unit"        "Entire villa"
# [4119] "Entire condo"              "Entire condo"
# [4121] "Entire condo"              "Entire home"
# [4123] "Entire home"               "Entire rental unit"
# [4125] "Entire rental unit"        "Entire condo"
# [4127] "Entire rental unit"        "Entire rental unit"
# [4129] "Entire condo"              "Entire rental unit"
# [4131] "Entire home"               "Entire rental unit"
# [4133] "Entire home"               "Entire rental unit"
# [4135] "Entire condo"              "Entire condo"
# [4137] "Entire home"               "Entire rental unit"
# [4139] "Entire condo"              "Entire home"
# [4141] "Entire rental unit"        "Entire loft"
# [4143] "Entire loft"               "Entire guest suite"
# [4145] "Entire condo"              "Entire rental unit"
# [4147] "Entire rental unit"        "Entire home"
# [4149] "Entire rental unit"        "Entire condo"
# [4151] "Entire rental unit"        "Entire home"
# [4153] "Entire home"               "Entire condo"
# [4155] "Entire home"               "Entire rental unit"
# [4157] "Entire condo"              "Entire condo"
# [4159] "Entire home"               "Entire rental unit"
# [4161] "Entire home"               "Entire home"
# [4163] "Entire condo"              "Entire rental unit"
# [4165] "Entire condo"              "Entire rental unit"
# [4167] "Entire rental unit"        "Entire rental unit"
# [4169] "Entire rental unit"        "Entire loft"
# [4171] "Entire condo"              "Entire rental unit"
# [4173] "Entire townhouse"          "Entire guest suite"
# [4175] "Entire rental unit"        "Entire guesthouse"
# [4177] "Entire guest suite"        "Entire condo"
# [4179] "Entire condo"              "Entire home"
# [4181] "Entire home"               "Entire home"
# [4183] "Entire rental unit"        "Entire rental unit"
# [4185] "Entire loft"               "Entire rental unit"
# [4187] "Entire home"               "Entire rental unit"
# [4189] "Entire rental unit"        "Entire guest suite"
# [4191] "Entire rental unit"        "Entire home"
# [4193] "Entire guest suite"        "Entire guesthouse"
# [4195] "Entire home"               "Entire home"
# [4197] "Entire condo"              "Entire rental unit"
# [4199] "Entire rental unit"        "Entire condo"
# [4201] "Entire home"               "Entire guesthouse"
# [4203] "Entire condo"              "Entire rental unit"
# [4205] "Entire home"               "Entire rental unit"
# [4207] "Entire rental unit"        "Entire rental unit"
# [4209] "Entire home"               "Entire condo"
# [4211] "Entire condo"              "Entire loft"
# [4213] "Entire rental unit"        "Entire guest suite"
# [4215] "Entire rental unit"        "Entire rental unit"
# [4217] "Entire condo"              "Entire rental unit"
# [4219] "Entire condo"              "Entire rental unit"
# [4221] "Entire home"               "Entire home"
# [4223] "Entire condo"              "Entire rental unit"
# [4225] "Entire loft"               "Entire rental unit"
# [4227] "Entire rental unit"        "Entire rental unit"
# [4229] "Entire condo"              "Entire condo"
# [4231] "Entire serviced apartment" "Entire home"
# [4233] "Entire condo"              "Entire condo"
# [4235] "Entire rental unit"        "Entire condo"
# [4237] "Entire guest suite"        "Entire guest suite"
# [4239] "Entire condo"              "Entire condo"
# [4241] "Entire rental unit"        "Entire rental unit"
# [4243] "Entire guest suite"        "Entire condo"
# [4245] "Entire home"               "Entire condo"
# [4247] "Entire home"               "Entire rental unit"
# [4249] "Entire condo"              "Entire guest suite"
# [4251] "Entire rental unit"        "Entire condo"
# [4253] "Entire guest suite"        "Entire home"
# [4255] "Entire guest suite"        "Entire rental unit"
# [4257] "Entire condo"              "Entire home"
# [4259] "Entire rental unit"        "Entire guesthouse"
# [4261] "Entire rental unit"        "Entire home"
# [4263] "Entire condo"              "Entire rental unit"
# [4265] "Entire guest suite"        "Entire condo"
# [4267] "Entire condo"              "Entire rental unit"
# [4269] "Entire home"               "Entire guest suite"
# [4271] "Entire condo"
